# %% [markdown]
# # FakeNewsGuard AI - Analysis Notebook
# This notebook outline mirrors the training pipeline in `train_model.py`.

# %%
import pandas as pd
df = pd.read_csv('../data/news_dataset.csv')
df.head()

# %%
df['label'].value_counts()

# %% [markdown]
# ## Next steps
# Use `train_model.py` for the reproducible training and evaluation pipeline.
